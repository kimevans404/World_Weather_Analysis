# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 774

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]    
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # city_descrip = weather_json["weather"][0]["description"]
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          # "Weather Description": city_descrip,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barisal
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | san juan bautista
# Processing Record 5 of Set 1 | san patricio
# Processing Record 6 of Set 1 | mlimba
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | arraial do cabo
# Processing Record 13 of Set 1 | labuhan
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | havre-saint-pierre
# Processing Record 16 of Set 1 | svetlogorsk
# Processing Record 17 of Set 1 | tekeli
# Processing Record 18 of Set 1 | bethel
# Processing Record 19 of Set 1 | adrar
# Processing Record 20 of Set 1 | westport
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | norfolk
# Processing Record 23 of Set 1 | cayenne
# Processing Record 24 of Set 1 | lebu
# Processing Record 25 of Set 1 | salihorsk
# Processing Record 26 of Set 1 | pilar
# Processing Record 27 of Set 1 | pevek
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | cabo san lucas
# Processing Record 31 of Set 1 | lorengau
# Processing Record 32 of Set 1 | fare
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | galle
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | basarabeasca
# Processing Record 38 of Set 1 | lagoa
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | sibolga
# Processing Record 41 of Set 1 | san cristobal
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 1 | vanavara
# Processing Record 45 of Set 1 | luderitz
# Processing Record 46 of Set 1 | san jose
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | iqaluit
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | tchibanga
# Processing Record 2 of Set 2 | dumas
# Processing Record 3 of Set 2 | richards bay
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 6 of Set 2 | esperance
# Processing Record 7 of Set 2 | ugep
# Processing Record 8 of Set 2 | laguna
# Processing Record 9 of Set 2 | amahai
# Processing Record 10 of Set 2 | bratsk
# Processing Record 11 of Set 2 | airai
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | marzuq
# Processing Record 14 of Set 2 | kataysk
# Processing Record 15 of Set 2 | gornopravdinsk
# Processing Record 16 of Set 2 | salalah
# Processing Record 17 of Set 2 | labuan
# Processing Record 18 of Set 2 | victoria
# Processing Record 19 of Set 2 | aksu
# Processing Record 20 of Set 2 | mitu
# Processing Record 21 of Set 2 | boffa
# Processing Record 22 of Set 2 | bingol
# Processing Record 23 of Set 2 | kodiak
# Processing Record 24 of Set 2 | north bend
# Processing Record 25 of Set 2 | hastings
# Processing Record 26 of Set 2 | castro
# Processing Record 27 of Set 2 | lewisporte
# Processing Record 28 of Set 2 | cidreira
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | necochea
# Processing Record 31 of Set 2 | chuy
# Processing Record 32 of Set 2 | codrington
# Processing Record 33 of Set 2 | cherskiy
# Processing Record 34 of Set 2 | port blair
# Processing Record 35 of Set 2 | faanui
# Processing Record 36 of Set 2 | san quintin
# Processing Record 37 of Set 2 | hovd
# Processing Record 38 of Set 2 | tessalit
# Processing Record 39 of Set 2 | narsaq
# Processing Record 40 of Set 2 | carnarvon
# Processing Record 41 of Set 2 | gravelbourg
# Processing Record 42 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 2 | denpasar
# Processing Record 44 of Set 2 | namatanai
# Processing Record 45 of Set 2 | cap-aux-meules
# Processing Record 46 of Set 2 | gizo
# Processing Record 47 of Set 2 | kapaa
# Processing Record 48 of Set 2 | kontagora
# Processing Record 49 of Set 2 | santa cruz cabralia
# Processing Record 50 of Set 2 | pecos
# Processing Record 1 of Set 3 | canelones
# Processing Record 2 of Set 3 | moranbah
# Processing Record 3 of Set 3 | grindavik
# Processing Record 4 of Set 3 | saint-augustin
# Processing Record 5 of Set 3 | atikokan
# Processing Record 6 of Set 3 | dikson
# Processing Record 7 of Set 3 | barrow
# Processing Record 8 of Set 3 | qasigiannguit
# Processing Record 9 of Set 3 | vostok
# Processing Record 10 of Set 3 | nizwa
# Processing Record 11 of Set 3 | conde
# Processing Record 12 of Set 3 | ternate
# Processing Record 13 of Set 3 | anadyr
# Processing Record 14 of Set 3 | sao felix do xingu
# Processing Record 15 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 3 | kaitangata
# Processing Record 17 of Set 3 | santa cruz
# Processing Record 18 of Set 3 | vestmanna
# Processing Record 19 of Set 3 | hithadhoo
# Processing Record 20 of Set 3 | les cayes
# Processing Record 21 of Set 3 | asasa
# Processing Record 22 of Set 3 | petawawa
# Processing Record 23 of Set 3 | hofn
# Processing Record 24 of Set 3 | georgetown
# Processing Record 25 of Set 3 | mangla
# Processing Record 26 of Set 3 | tasiilaq
# Processing Record 27 of Set 3 | pochutla
# Processing Record 28 of Set 3 | ayagoz
# Processing Record 29 of Set 3 | vila praia de ancora
# Processing Record 30 of Set 3 | ribeira grande
# Processing Record 31 of Set 3 | hobyo
# Processing Record 32 of Set 3 | pacific grove
# Processing Record 33 of Set 3 | kimbe
# Processing Record 34 of Set 3 | puerto ayacucho
# Processing Record 35 of Set 3 | vardo
# Processing Record 36 of Set 3 | port elizabeth
# Processing Record 37 of Set 3 | makakilo city
# Processing Record 38 of Set 3 | opuwo
# Processing Record 39 of Set 3 | khatanga
# Processing Record 40 of Set 3 | blois
# Processing Record 41 of Set 3 | kondinskoye
# Processing Record 42 of Set 3 | doliana
# Processing Record 43 of Set 3 | troitskoye
# Processing Record 44 of Set 3 | manokwari
# Processing Record 45 of Set 3 | yatou
# Processing Record 46 of Set 3 | east london
# Processing Record 47 of Set 3 | tiksi
# Processing Record 48 of Set 3 | barra do garcas
# Processing Record 49 of Set 3 | kaeo
# Processing Record 50 of Set 3 | eydhafushi
# Processing Record 1 of Set 4 | at-bashi
# Processing Record 2 of Set 4 | cabedelo
# Processing Record 3 of Set 4 | mahebourg
# Processing Record 4 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 4 | kajaani
# Processing Record 6 of Set 4 | coruripe
# Processing Record 7 of Set 4 | ahome
# Processing Record 8 of Set 4 | ilulissat
# Processing Record 9 of Set 4 | sao filipe
# Processing Record 10 of Set 4 | port alfred
# Processing Record 11 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 4 | erzin
# Processing Record 13 of Set 4 | itacurubi del rosario
# Processing Record 14 of Set 4 | avarua
# Processing Record 15 of Set 4 | yar-sale
# Processing Record 16 of Set 4 | store heddinge
# Processing Record 17 of Set 4 | coalcoman
# City not found. Skipping...
# Processing Record 18 of Set 4 | bodmin
# Processing Record 19 of Set 4 | thompson
# Processing Record 20 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 4 | saint-philippe
# Processing Record 22 of Set 4 | coelho neto
# Processing Record 23 of Set 4 | bathsheba
# Processing Record 24 of Set 4 | torbay
# Processing Record 25 of Set 4 | katsuura
# Processing Record 26 of Set 4 | vega de alatorre
# Processing Record 27 of Set 4 | sassandra
# Processing Record 28 of Set 4 | harper
# Processing Record 29 of Set 4 | carballo
# Processing Record 30 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 31 of Set 4 | bournemouth
# Processing Record 32 of Set 4 | bukama
# Processing Record 33 of Set 4 | sakakah
# Processing Record 34 of Set 4 | padina
# Processing Record 35 of Set 4 | gardiner
# Processing Record 36 of Set 4 | chokurdakh
# Processing Record 37 of Set 4 | bulgan
# Processing Record 38 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 4 | roros
# Processing Record 40 of Set 4 | sisimiut
# Processing Record 41 of Set 4 | bengkulu
# Processing Record 42 of Set 4 | mar del plata
# Processing Record 43 of Set 4 | aykhal
# Processing Record 44 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 4 | tiruchchendur
# Processing Record 46 of Set 4 | corinto
# Processing Record 47 of Set 4 | cockburn town
# Processing Record 48 of Set 4 | hailar
# Processing Record 49 of Set 4 | keti bandar
# Processing Record 50 of Set 4 | nueva concepcion
# Processing Record 1 of Set 5 | acari
# Processing Record 2 of Set 5 | sur
# Processing Record 3 of Set 5 | lishan
# Processing Record 4 of Set 5 | san-pedro
# Processing Record 5 of Set 5 | washington
# Processing Record 6 of Set 5 | constitucion
# Processing Record 7 of Set 5 | dymer
# Processing Record 8 of Set 5 | general roca
# Processing Record 9 of Set 5 | bongandanga
# Processing Record 10 of Set 5 | avera
# Processing Record 11 of Set 5 | alofi
# Processing Record 12 of Set 5 | marquette
# Processing Record 13 of Set 5 | saint george
# Processing Record 14 of Set 5 | antsirabe
# Processing Record 15 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 5 | seoul
# Processing Record 17 of Set 5 | san francisco
# Processing Record 18 of Set 5 | ixtapa
# Processing Record 19 of Set 5 | antofagasta
# Processing Record 20 of Set 5 | mayo
# Processing Record 21 of Set 5 | saskylakh
# Processing Record 22 of Set 5 | camocim
# Processing Record 23 of Set 5 | balkanabat
# Processing Record 24 of Set 5 | verkhnyaya toyma
# Processing Record 25 of Set 5 | ancud
# Processing Record 26 of Set 5 | estrela
# Processing Record 27 of Set 5 | mastic beach
# Processing Record 28 of Set 5 | moundou
# Processing Record 29 of Set 5 | guerrero negro
# Processing Record 30 of Set 5 | santo antonio do leverger
# Processing Record 31 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 5 | sobolevo
# Processing Record 33 of Set 5 | wawa
# Processing Record 34 of Set 5 | pingliang
# Processing Record 35 of Set 5 | kota belud
# Processing Record 36 of Set 5 | vila velha
# Processing Record 37 of Set 5 | waris aliganj
# Processing Record 38 of Set 5 | saint-pierre
# Processing Record 39 of Set 5 | agirish
# Processing Record 40 of Set 5 | zyryanka
# Processing Record 41 of Set 5 | ypsonas
# Processing Record 42 of Set 5 | miyako
# Processing Record 43 of Set 5 | meulaboh
# Processing Record 44 of Set 5 | matamoros
# Processing Record 45 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 5 | sorland
# Processing Record 47 of Set 5 | gomel
# Processing Record 48 of Set 5 | port antonio
# Processing Record 49 of Set 5 | ola
# Processing Record 50 of Set 5 | severo-kurilsk
# Processing Record 1 of Set 6 | sept-iles
# Processing Record 2 of Set 6 | flinders
# Processing Record 3 of Set 6 | muzaffarabad
# Processing Record 4 of Set 6 | vao
# Processing Record 5 of Set 6 | caravelas
# Processing Record 6 of Set 6 | mount isa
# Processing Record 7 of Set 6 | saldanha
# Processing Record 8 of Set 6 | evensk
# Processing Record 9 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 6 | thayetmyo
# Processing Record 11 of Set 6 | kavieng
# Processing Record 12 of Set 6 | antalaha
# Processing Record 13 of Set 6 | fortuna
# Processing Record 14 of Set 6 | kyren
# Processing Record 15 of Set 6 | charters towers
# Processing Record 16 of Set 6 | biltine
# Processing Record 17 of Set 6 | te anau
# Processing Record 18 of Set 6 | olhao
# Processing Record 19 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 6 | klaksvik
# Processing Record 21 of Set 6 | najran
# Processing Record 22 of Set 6 | mildura
# Processing Record 23 of Set 6 | amapa
# Processing Record 24 of Set 6 | ambilobe
# Processing Record 25 of Set 6 | pangnirtung
# Processing Record 26 of Set 6 | linjiang
# Processing Record 27 of Set 6 | vestmannaeyjar
# Processing Record 28 of Set 6 | michigan city
# Processing Record 29 of Set 6 | buguda
# Processing Record 30 of Set 6 | kenai
# Processing Record 31 of Set 6 | roald
# Processing Record 32 of Set 6 | yerbogachen
# Processing Record 33 of Set 6 | novopavlovka
# Processing Record 34 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 6 | tepalcatepec
# Processing Record 36 of Set 6 | wabag
# Processing Record 37 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 38 of Set 6 | bairiki
# Processing Record 39 of Set 6 | mamaku
# Processing Record 40 of Set 6 | bambous virieux
# Processing Record 41 of Set 6 | alihe
# Processing Record 42 of Set 6 | erdaojiang
# Processing Record 43 of Set 6 | buala
# Processing Record 44 of Set 6 | provideniya
# Processing Record 45 of Set 6 | orito
# Processing Record 46 of Set 6 | misratah
# Processing Record 47 of Set 6 | karabulak
# Processing Record 48 of Set 6 | makubetsu
# Processing Record 49 of Set 6 | amatitan
# Processing Record 50 of Set 6 | phan thiet
# Processing Record 1 of Set 7 | athabasca
# Processing Record 2 of Set 7 | vierzon
# Processing Record 3 of Set 7 | clovis
# Processing Record 4 of Set 7 | tondano
# Processing Record 5 of Set 7 | vygonichi
# Processing Record 6 of Set 7 | ahumada
# City not found. Skipping...
# Processing Record 7 of Set 7 | nikolskoye
# Processing Record 8 of Set 7 | miri
# Processing Record 9 of Set 7 | yingzhong
# City not found. Skipping...
# Processing Record 10 of Set 7 | yangambi
# Processing Record 11 of Set 7 | palmer
# Processing Record 12 of Set 7 | akdepe
# Processing Record 13 of Set 7 | sao joao da barra
# Processing Record 14 of Set 7 | krasnogorskoye
# Processing Record 15 of Set 7 | dakar
# Processing Record 16 of Set 7 | bitkine
# Processing Record 17 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 7 | mata
# Processing Record 19 of Set 7 | port hardy
# Processing Record 20 of Set 7 | juneau
# Processing Record 21 of Set 7 | asau
# Processing Record 22 of Set 7 | shenxian
# Processing Record 23 of Set 7 | champerico
# Processing Record 24 of Set 7 | ust-koksa
# Processing Record 25 of Set 7 | devils lake
# Processing Record 26 of Set 7 | suntar
# Processing Record 27 of Set 7 | cochrane
# Processing Record 28 of Set 7 | gagino
# Processing Record 29 of Set 7 | korla
# Processing Record 30 of Set 7 | olinda
# Processing Record 31 of Set 7 | buchanan
# Processing Record 32 of Set 7 | pangoa
# Processing Record 33 of Set 7 | ossora
# Processing Record 34 of Set 7 | san juan
# Processing Record 35 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 7 | sitka
# Processing Record 37 of Set 7 | hambantota
# Processing Record 38 of Set 7 | norman wells
# Processing Record 39 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 7 | kawasaki
# Processing Record 41 of Set 7 | port hedland
# Processing Record 42 of Set 7 | road town
# Processing Record 43 of Set 7 | katherine
# Processing Record 44 of Set 7 | vikhorevka
# Processing Record 45 of Set 7 | kruisfontein
# Processing Record 46 of Set 7 | rosetta
# Processing Record 47 of Set 7 | tabou
# Processing Record 48 of Set 7 | sayyan
# Processing Record 49 of Set 7 | buraydah
# Processing Record 50 of Set 7 | acapulco
# Processing Record 1 of Set 8 | zhanakorgan
# Processing Record 2 of Set 8 | varzea grande
# Processing Record 3 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 4 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 5 of Set 8 | benjamin hill
# Processing Record 6 of Set 8 | mehamn
# Processing Record 7 of Set 8 | puerto escondido
# Processing Record 8 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 9 of Set 8 | conceicao do araguaia
# Processing Record 10 of Set 8 | shache
# Processing Record 11 of Set 8 | cruzeiro do sul
# Processing Record 12 of Set 8 | naryan-mar
# Processing Record 13 of Set 8 | pervomayskiy
# Processing Record 14 of Set 8 | kalabo
# Processing Record 15 of Set 8 | mareeba
# Processing Record 16 of Set 8 | husavik
# Processing Record 17 of Set 8 | sidrolandia
# Processing Record 18 of Set 8 | eyl
# Processing Record 19 of Set 8 | khorramabad
# Processing Record 20 of Set 8 | pyaozerskiy
# Processing Record 21 of Set 8 | quatre cocos
# Processing Record 22 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 23 of Set 8 | goderich
# Processing Record 24 of Set 8 | do rud
# City not found. Skipping...
# Processing Record 25 of Set 8 | kalawit
# Processing Record 26 of Set 8 | talnakh
# Processing Record 27 of Set 8 | saint-louis
# Processing Record 28 of Set 8 | mujiayingzi
# Processing Record 29 of Set 8 | chipinge
# Processing Record 30 of Set 8 | la macarena
# Processing Record 31 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 8 | chateaubelair
# Processing Record 33 of Set 8 | vermilion
# Processing Record 34 of Set 8 | kalmunai
# Processing Record 35 of Set 8 | gulu
# Processing Record 36 of Set 8 | nancha
# Processing Record 37 of Set 8 | poplar bluff
# Processing Record 38 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 39 of Set 8 | zdvinsk
# Processing Record 40 of Set 8 | moses lake
# Processing Record 41 of Set 8 | hasaki
# Processing Record 42 of Set 8 | college
# Processing Record 43 of Set 8 | sambava
# Processing Record 44 of Set 8 | roma
# Processing Record 45 of Set 8 | labrea
# Processing Record 46 of Set 8 | jablah
# Processing Record 47 of Set 8 | maceio
# Processing Record 48 of Set 8 | rockhampton
# Processing Record 49 of Set 8 | ardakan
# Processing Record 50 of Set 8 | cerrito
# Processing Record 1 of Set 9 | kortkeros
# Processing Record 2 of Set 9 | rio gallegos
# Processing Record 3 of Set 9 | vigrestad
# Processing Record 4 of Set 9 | kloulklubed
# Processing Record 5 of Set 9 | katima mulilo
# Processing Record 6 of Set 9 | key west
# Processing Record 7 of Set 9 | alakurtti
# Processing Record 8 of Set 9 | tukrah
# Processing Record 9 of Set 9 | borinskoye
# Processing Record 10 of Set 9 | solok
# Processing Record 11 of Set 9 | auki
# Processing Record 12 of Set 9 | riyadh
# Processing Record 13 of Set 9 | illapel
# Processing Record 14 of Set 9 | ostrovnoy
# Processing Record 15 of Set 9 | zaysan
# Processing Record 16 of Set 9 | channagiri
# Processing Record 17 of Set 9 | manaskent
# Processing Record 18 of Set 9 | alekseyevsk
# Processing Record 19 of Set 9 | plouzane
# Processing Record 20 of Set 9 | bara
# Processing Record 21 of Set 9 | svetlyy
# Processing Record 22 of Set 9 | half moon bay
# Processing Record 23 of Set 9 | port maria
# Processing Record 24 of Set 9 | somoto
# Processing Record 25 of Set 9 | srednekolymsk
# Processing Record 26 of Set 9 | stromness
# Processing Record 27 of Set 9 | concordia
# Processing Record 28 of Set 9 | tromso
# Processing Record 29 of Set 9 | den helder
# Processing Record 30 of Set 9 | yenagoa
# Processing Record 31 of Set 9 | northam
# Processing Record 32 of Set 9 | bonavista
# Processing Record 33 of Set 9 | itaituba
# Processing Record 34 of Set 9 | dicamay
# Processing Record 35 of Set 9 | eureka
# Processing Record 36 of Set 9 | lompoc
# Processing Record 37 of Set 9 | svetlaya
# Processing Record 38 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 9 | kapuskasing
# Processing Record 40 of Set 9 | ritchie
# Processing Record 41 of Set 9 | coxim
# Processing Record 42 of Set 9 | parana
# Processing Record 43 of Set 9 | paita
# Processing Record 44 of Set 9 | valjala
# City not found. Skipping...
# Processing Record 45 of Set 9 | dedza
# Processing Record 46 of Set 9 | leningradskiy
# Processing Record 47 of Set 9 | praia da vitoria
# Processing Record 48 of Set 9 | chatra
# Processing Record 49 of Set 9 | sao jose da coroa grande
# Processing Record 50 of Set 9 | arrifes
# Processing Record 1 of Set 10 | skibbereen
# Processing Record 2 of Set 10 | uvat
# Processing Record 3 of Set 10 | tagbac
# Processing Record 4 of Set 10 | atasu
# Processing Record 5 of Set 10 | sola
# Processing Record 6 of Set 10 | meadow lake
# Processing Record 7 of Set 10 | egvekinot
# Processing Record 8 of Set 10 | port lincoln
# Processing Record 9 of Set 10 | matara
# Processing Record 10 of Set 10 | hualmay
# Processing Record 11 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 12 of Set 10 | hadejia
# Processing Record 13 of Set 10 | coquimbo
# Processing Record 14 of Set 10 | calvinia
# Processing Record 15 of Set 10 | yumen
# Processing Record 16 of Set 10 | kamalia
# Processing Record 17 of Set 10 | olafsvik
# Processing Record 18 of Set 10 | beyneu
# Processing Record 19 of Set 10 | arman
# Processing Record 20 of Set 10 | praya
# Processing Record 21 of Set 10 | geraldton
# Processing Record 22 of Set 10 | dakoro
# Processing Record 23 of Set 10 | berlevag
# Processing Record 24 of Set 10 | clyde river
# Processing Record 25 of Set 10 | ouadda
# Processing Record 26 of Set 10 | los llanos de aridane
# Processing Record 27 of Set 10 | hun
# Processing Record 28 of Set 10 | quelimane
# Processing Record 29 of Set 10 | muros
# Processing Record 30 of Set 10 | koungou
# Processing Record 31 of Set 10 | hamilton
# Processing Record 32 of Set 10 | andenes
# Processing Record 33 of Set 10 | dingle
# Processing Record 34 of Set 10 | tanshui
# City not found. Skipping...
# Processing Record 35 of Set 10 | manosque
# Processing Record 36 of Set 10 | kovdor
# Processing Record 37 of Set 10 | aasiaat
# Processing Record 38 of Set 10 | dingtao
# Processing Record 39 of Set 10 | yulara
# Processing Record 40 of Set 10 | comodoro rivadavia
# Processing Record 41 of Set 10 | bad ems
# Processing Record 42 of Set 10 | grand gaube
# Processing Record 43 of Set 10 | isangel
# Processing Record 44 of Set 10 | padang
# Processing Record 45 of Set 10 | erenhot
# Processing Record 46 of Set 10 | vila franca do campo
# Processing Record 47 of Set 10 | tungkang
# City not found. Skipping...
# Processing Record 48 of Set 10 | urumqi
# Processing Record 49 of Set 10 | naze
# Processing Record 50 of Set 10 | huancavelica
# Processing Record 1 of Set 11 | pallasovka
# Processing Record 2 of Set 11 | rock sound
# Processing Record 3 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 11 | saint-francois
# Processing Record 5 of Set 11 | graaff-reinet
# Processing Record 6 of Set 11 | poreba
# Processing Record 7 of Set 11 | grafton
# Processing Record 8 of Set 11 | sunbury
# Processing Record 9 of Set 11 | bereznik
# Processing Record 10 of Set 11 | abnub
# Processing Record 11 of Set 11 | duiwelskloof
# Processing Record 12 of Set 11 | zhuhai
# Processing Record 13 of Set 11 | waipawa
# Processing Record 14 of Set 11 | shingu
# Processing Record 15 of Set 11 | mont-de-marsan
# Processing Record 16 of Set 11 | sharjah
# Processing Record 17 of Set 11 | simao
# Processing Record 18 of Set 11 | alta floresta
# Processing Record 19 of Set 11 | tartagal
# Processing Record 20 of Set 11 | villa rica
# Processing Record 21 of Set 11 | kindu
# Processing Record 22 of Set 11 | jalu
# Processing Record 23 of Set 11 | karacakoy
# Processing Record 24 of Set 11 | hella
# Processing Record 25 of Set 11 | mandal
# Processing Record 26 of Set 11 | nemuro
# Processing Record 27 of Set 11 | alcaniz
# Processing Record 28 of Set 11 | dawlatabad
# Processing Record 29 of Set 11 | souillac
# Processing Record 30 of Set 11 | kareli
# Processing Record 31 of Set 11 | wadi musa
# Processing Record 32 of Set 11 | lagos
# Processing Record 33 of Set 11 | mammaste
# Processing Record 34 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 11 | loudi
# Processing Record 36 of Set 11 | itoman
# Processing Record 37 of Set 11 | ingham
# Processing Record 38 of Set 11 | aklavik
# Processing Record 39 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 40 of Set 11 | touros
# Processing Record 41 of Set 11 | saint anthony
# Processing Record 42 of Set 11 | komsomolskiy
# Processing Record 43 of Set 11 | oskemen
# Processing Record 44 of Set 11 | dublin
# Processing Record 45 of Set 11 | shediac
# Processing Record 46 of Set 11 | strezhevoy
# Processing Record 47 of Set 11 | kudahuvadhoo
# Processing Record 48 of Set 11 | mitsamiouli
# Processing Record 49 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 11 | businga
# Processing Record 1 of Set 12 | sinnamary
# Processing Record 2 of Set 12 | singkang
# Processing Record 3 of Set 12 | ahipara
# Processing Record 4 of Set 12 | fort nelson
# Processing Record 5 of Set 12 | kandi
# Processing Record 6 of Set 12 | ust-maya
# Processing Record 7 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 8 of Set 12 | prabumulih
# Processing Record 9 of Set 12 | yilan
# Processing Record 10 of Set 12 | jibuti
# Processing Record 11 of Set 12 | puerto cabezas
# Processing Record 12 of Set 12 | asmara
# Processing Record 13 of Set 12 | bahia blanca
# Processing Record 14 of Set 12 | upernavik
# Processing Record 15 of Set 12 | simpang
# Processing Record 16 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 12 | ashqelon
# Processing Record 18 of Set 12 | teya
# Processing Record 19 of Set 12 | nanzhang
# Processing Record 20 of Set 12 | obo
# Processing Record 21 of Set 12 | blackwater
# Processing Record 22 of Set 12 | dunajska streda
# Processing Record 23 of Set 12 | morant bay
# Processing Record 24 of Set 12 | senador jose porfirio
# Processing Record 25 of Set 12 | ayan
# Processing Record 26 of Set 12 | bontang
# Processing Record 27 of Set 12 | lakes entrance
# Processing Record 28 of Set 12 | payo
# Processing Record 29 of Set 12 | shahrud
# Processing Record 30 of Set 12 | deputatskiy
# Processing Record 31 of Set 12 | shumskiy
# Processing Record 32 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 33 of Set 12 | ostersund
# Processing Record 34 of Set 12 | raga
# Processing Record 35 of Set 12 | skowhegan
# Processing Record 36 of Set 12 | yingcheng
# Processing Record 37 of Set 12 | olga
# Processing Record 38 of Set 12 | henties bay
# Processing Record 39 of Set 12 | ranong
# Processing Record 40 of Set 12 | emmauss
# Processing Record 41 of Set 12 | manaure
# Processing Record 42 of Set 12 | lander
# Processing Record 43 of Set 12 | ornskoldsvik
# Processing Record 44 of Set 12 | sovetskiy
# Processing Record 45 of Set 12 | maues
# Processing Record 46 of Set 12 | booue
# Processing Record 47 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 48 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 49 of Set 12 | matay
# Processing Record 50 of Set 12 | marrakesh
# Processing Record 1 of Set 13 | port pirie
# Processing Record 2 of Set 13 | millinocket
# Processing Record 3 of Set 13 | ponta do sol
# Processing Record 4 of Set 13 | shchelyayur
# City not found. Skipping...
# Processing Record 5 of Set 13 | aitape
# Processing Record 6 of Set 13 | kargasok
# Processing Record 7 of Set 13 | tomatlan
# Processing Record 8 of Set 13 | hukuntsi
# Processing Record 9 of Set 13 | marawi
# Processing Record 10 of Set 13 | bilma
# Processing Record 11 of Set 13 | zhumadian
# Processing Record 12 of Set 13 | kuloy
# Processing Record 13 of Set 13 | fez
# Processing Record 14 of Set 13 | constantine
# Processing Record 15 of Set 13 | nanortalik
# Processing Record 16 of Set 13 | oktyabrskiy
# Processing Record 17 of Set 13 | boa vista
# Processing Record 18 of Set 13 | espanola
# Processing Record 19 of Set 13 | la serena
# Processing Record 20 of Set 13 | ajdabiya
# Processing Record 21 of Set 13 | mairana
# Processing Record 22 of Set 13 | kidal
# Processing Record 23 of Set 13 | camacha
# Processing Record 24 of Set 13 | lac du bonnet
# Processing Record 25 of Set 13 | sabang
# Processing Record 26 of Set 13 | nioro
# Processing Record 27 of Set 13 | reconquista
# Processing Record 28 of Set 13 | taphan hin
# Processing Record 29 of Set 13 | shelburne
# Processing Record 30 of Set 13 | longyearbyen
# Processing Record 31 of Set 13 | tecoanapa
# Processing Record 32 of Set 13 | razole
# Processing Record 33 of Set 13 | am timan
# Processing Record 34 of Set 13 | chauk
# Processing Record 35 of Set 13 | lahat
# Processing Record 36 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 37 of Set 13 | basco
# Processing Record 38 of Set 13 | hami
# Processing Record 39 of Set 13 | petropavl
# Processing Record 40 of Set 13 | bayevo
# Processing Record 41 of Set 13 | catemaco
# Processing Record 42 of Set 13 | petatlan
# Processing Record 43 of Set 13 | molina
# Processing Record 44 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 45 of Set 13 | karratha
# Processing Record 46 of Set 13 | kiambu
# Processing Record 47 of Set 13 | cowra
# Processing Record 48 of Set 13 | ayorou
# Processing Record 49 of Set 13 | oriximina
# Processing Record 50 of Set 13 | santiago del estero
# Processing Record 1 of Set 14 | wynyard
# Processing Record 2 of Set 14 | tuatapere
# Processing Record 3 of Set 14 | felanitx
# Processing Record 4 of Set 14 | bintulu
# Processing Record 5 of Set 14 | banjar
# Processing Record 6 of Set 14 | ningbo
# Processing Record 7 of Set 14 | traverse city
# Processing Record 8 of Set 14 | ulladulla
# Processing Record 9 of Set 14 | biak
# Processing Record 10 of Set 14 | faya
# Processing Record 11 of Set 14 | quibdo
# Processing Record 12 of Set 14 | slavsk
# Processing Record 13 of Set 14 | itarema
# Processing Record 14 of Set 14 | burica
# City not found. Skipping...
# Processing Record 15 of Set 14 | griffith
# Processing Record 16 of Set 14 | noumea
# Processing Record 17 of Set 14 | capaci
# Processing Record 18 of Set 14 | ust-kulom
# Processing Record 19 of Set 14 | kiruna
# Processing Record 20 of Set 14 | ballina
# Processing Record 21 of Set 14 | poum
# Processing Record 22 of Set 14 | pisco
# Processing Record 23 of Set 14 | belaya gora
# Processing Record 24 of Set 14 | leh
# Processing Record 25 of Set 14 | teacapan
# Processing Record 26 of Set 14 | tura
# Processing Record 27 of Set 14 | lavrentiya
# Processing Record 28 of Set 14 | zwedru
# Processing Record 29 of Set 14 | kakonko
# Processing Record 30 of Set 14 | laizhou
# Processing Record 31 of Set 14 | pimenta bueno
# Processing Record 32 of Set 14 | chenghai
# Processing Record 33 of Set 14 | la ronge
# Processing Record 34 of Set 14 | tacambaro
# City not found. Skipping...
# Processing Record 35 of Set 14 | tilichiki
# Processing Record 36 of Set 14 | chapais
# Processing Record 37 of Set 14 | high level
# Processing Record 38 of Set 14 | wanaka
# Processing Record 39 of Set 14 | borlange
# City not found. Skipping...
# Processing Record 40 of Set 14 | bilibino
# Processing Record 41 of Set 14 | coos bay
# Processing Record 42 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 43 of Set 14 | byron bay
# Processing Record 44 of Set 14 | umm lajj
# Processing Record 45 of Set 14 | ewa beach
# Processing Record 46 of Set 14 | alenquer
# Processing Record 47 of Set 14 | pekan nenas
# Processing Record 48 of Set 14 | loknya
# Processing Record 49 of Set 14 | wajima
# Processing Record 50 of Set 14 | tibati
# Processing Record 1 of Set 15 | vrangel
# Processing Record 2 of Set 15 | wewak
# Processing Record 3 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 4 of Set 15 | rawson
# Processing Record 5 of Set 15 | maniitsoq
# Processing Record 6 of Set 15 | shubarshi
# Processing Record 7 of Set 15 | mount barker
# Processing Record 8 of Set 15 | tahoua
# Processing Record 9 of Set 15 | sofiysk
# City not found. Skipping...
# Processing Record 10 of Set 15 | maraa
# Processing Record 11 of Set 15 | lovington
# Processing Record 12 of Set 15 | qorveh
# Processing Record 13 of Set 15 | praia
# Processing Record 14 of Set 15 | lumphat
# Processing Record 15 of Set 15 | aberdeen
# Processing Record 16 of Set 15 | ekibastuz
# Processing Record 17 of Set 15 | kununurra
# Processing Record 18 of Set 15 | saint-ambroise
# Processing Record 19 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 15 | broome
# Processing Record 21 of Set 15 | beloha
# Processing Record 22 of Set 15 | soure
# Processing Record 23 of Set 15 | gulfport
# Processing Record 24 of Set 15 | priboj
# Processing Record 25 of Set 15 | mandera
# Processing Record 26 of Set 15 | nichinan
# Processing Record 27 of Set 15 | nhulunbuy
# Processing Record 28 of Set 15 | puerto leguizamo
# Processing Record 29 of Set 15 | mogadishu
# Processing Record 30 of Set 15 | uyuni
# Processing Record 31 of Set 15 | uwayl
# City not found. Skipping...
# Processing Record 32 of Set 15 | maldonado
# Processing Record 33 of Set 15 | natal
# Processing Record 34 of Set 15 | mecca
# Processing Record 35 of Set 15 | the valley
# Processing Record 36 of Set 15 | haines junction
# Processing Record 37 of Set 15 | rio grande
# Processing Record 38 of Set 15 | luoyang
# Processing Record 39 of Set 15 | moose factory
# Processing Record 40 of Set 15 | nianzishan
# Processing Record 41 of Set 15 | alekseyevka
# Processing Record 42 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 43 of Set 15 | savelugu
# Processing Record 44 of Set 15 | nesna
# Processing Record 45 of Set 15 | nabisar
# Processing Record 46 of Set 15 | mporokoso
# Processing Record 47 of Set 15 | wainwright
# Processing Record 48 of Set 15 | boguchany
# Processing Record 49 of Set 15 | mount pleasant
# Processing Record 50 of Set 15 | ketchikan
# Processing Record 1 of Set 16 | viedma
# Processing Record 2 of Set 16 | port keats
# Processing Record 3 of Set 16 | nola
# Processing Record 4 of Set 16 | ibra
# Processing Record 5 of Set 16 | chicama
# Processing Record 6 of Set 16 | kahului
# Processing Record 7 of Set 16 | stroud
# Processing Record 8 of Set 16 | alice springs
# Processing Record 9 of Set 16 | nelson bay
# Processing Record 10 of Set 16 | springdale
# Processing Record 11 of Set 16 | lisakovsk
# Processing Record 12 of Set 16 | beringovskiy
# Processing Record 13 of Set 16 | gunnedah
# Processing Record 14 of Set 16 | atar
# Processing Record 15 of Set 16 | nizhniy chir
# Processing Record 16 of Set 16 | skage
# City not found. Skipping...
# Processing Record 17 of Set 16 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 16 | axim
# Processing Record 19 of Set 16 | oeiras
# Processing Record 20 of Set 16 | bejar
# Processing Record 21 of Set 16 | bosobolo
# Processing Record 22 of Set 16 | miandrivazo
# Processing Record 23 of Set 16 | cockburn harbour
# City not found. Skipping...
# Processing Record 24 of Set 16 | moussoro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 715

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Barisal  22.7019   90.3711     82.76        81          24
# 1             Albany  42.6001  -73.9662     52.74        91          12
# 2              Bluff -46.6000  168.3333     47.80        61          95
# 3  San Juan Bautista -14.0108  -75.7358     65.07        59           0
# 4       San Patricio  28.0170  -97.5169     78.84        57           7
# 5             Mlimba  -8.8000   35.8167     66.92        75          35
# 6          Cape Town -33.9258   18.4232     61.38        77          20
# 7            Mataura -46.1927  168.8643     47.48        91          73
# 8            Qaanaaq  77.4840  -69.3632      5.25        70          35
# 9            Ushuaia -54.8000  -68.3000     38.86        93         100
#
#    Wind Speed Country
# 0        6.11      BD
# 1        4.14      US
# 2       21.59      NZ
# 3        1.23      PE
# 4        8.41      US
# 5        2.15      TZ
# 6        6.91      ZA
# 7       10.65      NZ
# 8        7.92      GL
# 9       29.93      AR

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed"]

# Recreate the DataFrame by using the new column order
new_order_df = city_data_df[new_column_order]

# Display sample data
new_order_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Barisal      BD  22.7019   90.3711     82.76        81
# 1             Albany      US  42.6001  -73.9662     52.74        91
# 2              Bluff      NZ -46.6000  168.3333     47.80        61
# 3  San Juan Bautista      PE -14.0108  -75.7358     65.07        59
# 4       San Patricio      US  28.0170  -97.5169     78.84        57
# 5             Mlimba      TZ  -8.8000   35.8167     66.92        75
# 6          Cape Town      ZA -33.9258   18.4232     61.38        77
# 7            Mataura      NZ -46.1927  168.8643     47.48        91
# 8            Qaanaaq      GL  77.4840  -69.3632      5.25        70
# 9            Ushuaia      AR -54.8000  -68.3000     38.86        93
#
#    Cloudiness  Wind Speed
# 0          24        6.11
# 1          12        4.14
# 2          95       21.59
# 3           0        1.23
# 4           7        8.41
# 5          35        2.15
# 6          20        6.91
# 7          73       10.65
# 8          35        7.92
# 9         100       29.93

# %%
# Display the data types of each column by using the dtypes Pandas function
new_order_df.dtypes
# Out:
# City           object
# Country        object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "./WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
new_order_df.to_csv(output_data_file, index_label="City_ID")
